# %% [markdown]
# # San Francisco Rental Prices Dashboard
#
# In this notebook, you will compile the visualizations from the previous analysis into functions that can be used for a Panel dashboard.

# %%
# imports
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import os
from pathlib import Path
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-1-2a2a9a35167e> in <module>
#       4 import plotly.express as px
#       5 import pandas as pd
# ----> 6 import hvplot.pandas
#       7 import matplotlib.pyplot as plt
#       8 import os
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\hvplot\pandas.py in <module>
#      25     post_patch(extension, logo)
#      26
# ---> 27 patch()
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\hvplot\pandas.py in patch(name, interactive, extension, logo)
#      23     setattr(pd.Series, interactive, interactive_prop)
#      24
# ---> 25     post_patch(extension, logo)
#      26
#      27 patch()
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\hvplot\__init__.py in post_patch(extension, logo)
#     110 def post_patch(extension='bokeh', logo=False):
#     111     if extension and not getattr(_hv.extension, '_loaded', False):
# --> 112         _hv.extension(extension, logo=logo)
#     113
#     114
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\param\parameterized.py in __new__(class_, *args, **params)
#    3098         inst = class_.instance()
#    3099         inst.param._set_name(class_.__name__)
# -> 3100         return inst.__call__(*args,**params)
#    3101
#    3102     def __call__(self,*args,**kw):
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\holoviews\ipython\__init__.py in __call__(self, *args, **params)
#     186         for r in [r for r in resources if r != 'holoviews']:
#     187             Store.renderers[r].load_nb(inline=p.inline)
# --> 188         Renderer.load_nb(inline=p.inline)
#     189
#     190         if hasattr(ip, 'kernel') and not loaded:
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\holoviews\plotting\renderer.py in load_nb(cls, inline)
#     681         in the Jupyter notebook
#     682         """
# --> 683         load_notebook(inline)
#     684         with param.logging_level('ERROR'):
#     685             try:
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\panel\io\notebook.py in load_notebook(inline, load_timeout)
#     242     resources = Resources.from_bokeh(resources)
#     243     try:
# --> 244         bundle = bundle_resources(resources)
#     245         bundle = Bundle.from_bokeh(bundle)
#     246         configs, requirements, exports, skip_imports = require_components()
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\panel\io\resources.py in bundle_resources(resources)
#     108     css_raw = []
#     109
# --> 110     js_files.extend(js_resources.js_files)
#     111     js_raw.extend(js_resources.js_raw)
#     112
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\panel\io\resources.py in js_files(self)
#     183         from ..reactive import ReactiveHTML
#     184
# --> 185         files = super(Resources, self).js_files
#     186
#     187         for model in param.concrete_descendents(ReactiveHTML).values():
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\bokeh\resources.py in js_files(self)
#     434     @property
#     435     def js_files(self):
# --> 436         files, _, __ = self._resolve("js")
#     437         external_resources = self._collect_external_resources("__javascript__")
#     438         return external_resources + files
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\bokeh\resources.py in _resolve(self, kind)
#     351
#     352         if self.mode == "inline":
# --> 353             raw = [self._inline(path) for path in paths]
#     354         elif self.mode == "relative":
#     355             root_dir = self.root_dir or self._default_root_dir
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\bokeh\resources.py in <listcomp>(.0)
#     351
#     352         if self.mode == "inline":
# --> 353             raw = [self._inline(path) for path in paths]
#     354         elif self.mode == "relative":
#     355             root_dir = self.root_dir or self._default_root_dir
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\bokeh\resources.py in _inline(path)
#     372         begin = "/* BEGIN %s */" % basename(path)
#     373         with open(path, "rb") as f:
# --> 374             middle = f.read().decode("utf-8")
#     375         end = "/* END %s */" % basename(path)
#     376         return "%s\n%s\n%s" % (begin, middle, end)
#
# MemoryError:

# %%
# Read the Mapbox API key
load_dotenv()
MAP_BOX_API = os.getenv("MAP_BOX_API")
px.set_mapbox_access_token(MAP_BOX_API)

# %% [markdown]
# # Import Data

# %%
# Import the necessary CSVs to Pandas DataFrames
# YOUR CODE HERE!
file_path = Path("Data/sfo_neighborhoods_census_data.csv")
sfo_data = pd.read_csv(file_path, index_col="year")
sfo_data

# %% [markdown]
# - - -

# %% [markdown]
# ## Panel Visualizations
#
# In this section, you will copy the code for each plot type from your analysis notebook and place it into separate functions that Panel can use to create panes for the dashboard.
#
# These functions will convert the plot object to a Panel pane.
#
# Be sure to include any DataFrame transformation/manipulation code required along with the plotting code.
#
# Return a Panel pane object from each function that can be used to build the dashboard.
#
# Note: Remove any `.show()` lines from the code. We want to return the plots instead of showing them. The Panel dashboard will then display the plots.

# %%
# Define Panel Visualization Functions
def housing_units_per_year():
    """Housing Units Per Year."""
    
    # YOUR CODE HERE!


def average_gross_rent():
    """Average Gross Rent in San Francisco Per Year."""
    
    # YOUR CODE HERE!



def average_sales_price():
    """Average Sales Price Per Year."""
    
    # YOUR CODE HERE!



def average_price_by_neighborhood():
    """Average Prices by Neighborhood."""
    
    # YOUR CODE HERE!



def top_most_expensive_neighborhoods():
    """Top 10 Most Expensive Neighborhoods."""

    # YOUR CODE HERE!


def most_expensive_neighborhoods_rent_sales():
    """Comparison of Rent and Sales Prices of Most Expensive Neighborhoods."""   
    
    # YOUR CODE HERE!

    
    
def parallel_coordinates():
    """Parallel Coordinates Plot."""

    # YOUR CODE HERE!



def parallel_categories():
    """Parallel Categories Plot."""
    
    # YOUR CODE HERE!



def neighborhood_map():
    """Neighborhood Map."""

    # YOUR CODE HERE!


def sunburst():
    """Sunburst Plot."""
    
    # YOUR CODE HERE!

# %% [markdown]
# ## Panel Dashboard
#
# In this section, you will combine all of the plots into a single dashboard view using Panel. Be creative with your dashboard design!

# %%
# Create a Title for the Dashboard
# YOUR CODE HERE!


# Create a tab layout for the dashboard
# YOUR CODE HERE!


# Create the dashboard
# YOUR CODE HERE!

# %% [markdown]
# ## Serve the Panel Dashboard

# %%
# Serve the# dashboard
# YOUR CODE HERE!

# %% [markdown]
# # Debugging
#
# Note: Some of the Plotly express plots may not render in the notebook through the panel functions.
#
# However, you can test each plot by uncommenting the following code

# %%
# housing_units_per_year()

# %%
# average_gross_rent()

# %%
# average_sales_price()

# %%
# average_price_by_neighborhood()

# %%
# top_most_expensive_neighborhoods()

# %%
# most_expensive_neighborhoods_rent_sales()

# %%
# neighborhood_map().show()

# %%
# parallel_categories()

# %%
# parallel_coordinates()

# %%
# sunburst()
